# %% [markdown]
# ### 使用 宽 576 高 768 预处理

# %%
### 设定namelist
import json
name_list = ["Akaset","QingHao","Ennis","Alisa","SakuyaMako"]

name_list_arg = json.dumps(name_list).replace("\"", "\\\"")
name_list_arg = f'\"{name_list_arg}\"'
print(name_list_arg)
# Out:
# "[\"Akaset\", \"QingHao\", \"Ennis\", \"Alisa\", \"SakuyaMako\"]"

# %%
### 构建训练集
# !node tools/buildTrainset --name_list {name_list_arg}
# Out:
# 当前目录: k:\Model\StabilityDiffusion\lora训练
# 命令行参数: [
#   'E:\\nodejs\\node.exe',
#   'k:\\Model\\StabilityDiffusion\\lora训练\\tools\\buildTrainset',
#   '--name_list',
#   '["Akaset", "QingHao", "Ennis", "Alisa"]'
# ]
# 解析结果: { name_list: [ 'Akaset', 'QingHao', 'Ennis', 'Alisa' ] }
# k:\Model\StabilityDiffusion\lora训练\TraingSet\Akaset\build\5_AkasetPV
# k:\Model\StabilityDiffusion\lora训练\TraingSet\Akaset\build\1_AkasetVanilla
# k:\Model\StabilityDiffusion\lora训练\TraingSet\Akaset\build\1_AkasetDeepSea
# k:\Model\StabilityDiffusion\lora训练\TraingSet\Akaset\build\1_AkasetBlackCat
# k:\Model\StabilityDiffusion\lora训练\TraingSet\Akaset\build\1_AkasetBlackShark
# k:\Model\StabilityDiffusion\lora训练\TraingSet\Akaset\build\5_AkasetOther
# k:\Model\StabilityDiffusion\lora训练\TraingSet\QingHao\build\1_QingHaoVanilla
# k:\Model\StabilityDiffusion\lora训练\TraingSet\QingHao\build\1_QingHaoOther
# k:\Model\StabilityDiffusion\lora训练\TraingSet\Ennis\build\1_EnnisVanilla
# ...

# %%
### 检查训练集提示
# !node tools/tagStat --name_list {name_list_arg}
# Out:
# 当前目录: k:\Model\StabilityDiffusion\lora训练
# 命令行参数: [
#   'C:\\Environment\\nodejs\\node.exe',
#   'k:\\Model\\StabilityDiffusion\\lora训练\\tools\\tagStat',
#   '--name_list',
#   '["Akaset", "QingHao", "Ennis", "Alisa", "SakuyaMako"]'
# ]
# 解析结果: { name_list: [ 'Akaset', 'QingHao', 'Ennis', 'Alisa', 'SakuyaMako' ] }
# Akaset:
# {
#   '1girl': 200,
#   akaset: 200,
#   solo: 198,
#   white_background: 171,
#   simple_background: 165,
#   thighhighs: 143,
#   bare_shoulders: 138,
#   looking_at_viewer: 137,
#   breasts: 137,
#   full_body: 132,
#   hair_between_eyes: 131,
#   black_legwear: 131,
#   short_hair: 116,
#   standing: 113,
#   collarbone: 102,
#   bangs: 97,
#   closed_mouth: 97,
#   grey_eyes: 91,
#   dress: 90,
#   hair_ornament: 86,
#   silver_hair: 84,
#   eyebrows_visible_through_hair: 82,
#   smile: 64,
#   white_dress: 64,
#   zettai_ryouiki: 62,
#   small_breasts: 62,
#   akaset_vanilla: 60,
#   bare_arms: 54,
#   long_hair: 49,
#   jewelry: 39,
#   swimsuit: 39,
# ...

# %%
### 白底转换
input_folder = "TraingSet/Alisa/resource/透明底"
output_folder = "TraingSet/Alisa/resource/白底"
# !node tools/addWriteBG -i {input_folder} -o {output_folder}
# Out:
# 当前目录: k:\Model\StabilityDiffusion\lora训练
# 命令行参数: [
#   'E:\\nodejs\\node.exe',
#   'k:\\Model\\StabilityDiffusion\\lora训练\\tools\\addWriteBG',
#   '-i',
#   'TraingSet/Alisa/resource/透明底',
#   '-o',
#   'TraingSet/Alisa/resource/白底'
# ]
# 解析结果: {
#   input: 'TraingSet/Alisa/resource/透明底',
#   output: 'TraingSet/Alisa/resource/白底'
# }
# 读取输入文件夹: TraingSet/Alisa/resource/透明底
# 文件列表: [
#   'Image_Alisa_Dress_01_Battle01.png',
#   'Image_Alisa_Dress_02_Battle01.png'
# ]
# 处理文件: TraingSet\Alisa\resource\透明底\Image_Alisa_Dress_01_Battle01.png
# 处理文件: TraingSet\Alisa\resource\透明底\Image_Alisa_Dress_02_Battle01.png
# 保存图片成功: TraingSet\Alisa\resource\白底\Image_Alisa_Dress_02_Battle01.png
# 保存图片成功: TraingSet\Alisa\resource\白底\Image_Alisa_Dress_01_Battle01.png
